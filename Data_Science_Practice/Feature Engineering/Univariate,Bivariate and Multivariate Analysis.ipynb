# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
#%matplotlib.line

# %% [markdown]
# df=pd.read_csv(r"Datasets\iris.csv")
# df.head()
# df.shape

# %% [markdown]
# # Univariate Analysis

# %%
df.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
df['species'].value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        50
# Name: species, dtype: int64

# %%
df_setosa=df.loc[df['species']=='setosa']
df_virginica=df.loc[df['species']=='virginica']
df_versicolor=df.loc[df['species']=='versicolor']

# %%
plt.plot(df_setosa['sepal_length'],np.zeros_like(df_setosa['sepal_length']),'o')
plt.plot(df_virginica['sepal_length'],np.zeros_like(df_virginica['sepal_length']),'o')
plt.plot(df_versicolor['sepal_length'],np.zeros_like(df_versicolor['sepal_length']),'o')
plt.xlabel("sepal length")
# Out:
# Text(0.5, 0, 'sepal length')

# %%
plt.plot(df_setosa['sepal_length'],np.zeros_like(df_setosa['sepal_length']),'o')
plt.plot(df_virginica['sepal_length'],np.zeros_like(df_virginica['sepal_length']),'o')

# %%
plt.plot(df_setosa['sepal_length'],np.zeros_like(df_setosa['sepal_length']),'o')

# %% [markdown]
# # BiVariate Analysis

# %%
import seaborn as sns
sns.FacetGrid(df,hue='species',size=5).map(plt.scatter,"petal_length","sepal_width").add_legend()
plt.show()

# %%
sns.FacetGrid(df,size=5).map(plt.scatter,"petal_length","sepal_width").add_legend()
#without hue

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,hue='species')
#From the graphs below, Petal length and petal width  has high correlation, as one is increasing,another one also increasing
